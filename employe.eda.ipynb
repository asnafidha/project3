# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv(r'C:\Users\Dell\Downloads\archive (9)\Employee.csv')
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
data.shape
# Out:
# (4653, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
data.describe().T
# Out:
#                             count         mean       std     min     25%  \
# JoiningYear                4653.0  2015.062970  1.863377  2012.0  2013.0
# PaymentTier                4653.0     2.698259  0.561435     1.0     3.0
# Age                        4653.0    29.393295  4.826087    22.0    26.0
# ExperienceInCurrentDomain  4653.0     2.905652  1.558240     0.0     2.0
# LeaveOrNot                 4653.0     0.343864  0.475047     0.0     0.0
#
#                               50%     75%     max
# JoiningYear                2015.0  2017.0  2018.0
# PaymentTier                   3.0     3.0     3.0
# Age                          28.0    32.0    41.0
# ExperienceInCurrentDomain     3.0     4.0     7.0
# LeaveOrNot                    0.0     1.0     1.0

# %%
data.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1889

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (2764, 9)

# %%
data["Education"].unique()
# Out:
# array(['Bachelors', 'Masters', 'PHD'], dtype=object)

# %%
data["City"].unique()
# Out:
# array(['Bangalore', 'Pune', 'New Delhi'], dtype=object)

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data["EverBenched"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data["LeaveOrNot"].value_counts()
# Out:
# 0    1676
# 1    1088
# Name: LeaveOrNot, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data, x=data["LeaveOrNot"], color="red")
plt.show()

# %%
data["Education"].value_counts()
# Out:
# Bachelors    1971
# Masters       637
# PHD           156
# Name: Education, dtype: int64

# %%
sns.countplot(data=data, x= data["Education"], hue="LeaveOrNot", color="red")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
data["Gender"].value_counts()
# Out:
# Male      1529
# Female    1235
# Name: Gender, dtype: int64

# %%
sns.countplot(data=data, x= data["Gender"], hue="LeaveOrNot", color="blue")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
data["City"].value_counts()
# Out:
# Bangalore    1171
# Pune          801
# New Delhi     792
# Name: City, dtype: int64

# %%
sns.countplot(data=data, x= data["City"], hue="LeaveOrNot")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
data["EverBenched"].value_counts()
# Out:
# No     2403
# Yes     361
# Name: EverBenched, dtype: int64

# %%
sns.countplot(data=data, x= data["EverBenched"], hue="LeaveOrNot", color="green")
# Out:
# <Axes: xlabel='EverBenched', ylabel='count'>

# %%
sns.histplot(data=data, x=data["JoiningYear"],hue="LeaveOrNot", kde=True, bins=6, multiple="stack")
# Out:
# <Axes: xlabel='JoiningYear', ylabel='Count'>

# %%
sns.histplot(data=data, x=data["PaymentTier"],hue="LeaveOrNot", kde=True, bins=3, multiple="stack")
# Out:
# <Axes: xlabel='PaymentTier', ylabel='Count'>

# %%
sns.histplot(data=data, x=data["Age"],hue="LeaveOrNot", kde=True, bins=20, multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=data, x=data["ExperienceInCurrentDomain"],hue="LeaveOrNot", kde=True, bins=7, multiple="stack")
# Out:
# <Axes: xlabel='ExperienceInCurrentDomain', ylabel='Count'>
